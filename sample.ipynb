# %%
import utils.json_funcs
import main_classes as raw
import base_classes as bc

# %%
import pandas as pd
import utils.db as db

# %%
m1 = bc.MatchTest(1)
m2 = bc.MatchTest(2)
m1.id_date=10
print(m1.id_schedule)
print(m1.id_date)
print(m2.id_schedule)
print(m2.id_date)
# Out:
# 1
# 10
# 2
# -1

# %%
m1 = bc.MatchTest(1)

# %%
sql: str = "select id_season, id_league from raw.league_season"
df: pd.DataFrame = db.get_df(sql)
df = df.reset_index()  
season_league_dict = dict()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\io\sql.py:2664, in SQLiteDatabase.execute(self, sql, params)
#    2663 try:
# -> 2664     cur.execute(sql, *args)
#    2665     return cur
#
# OperationalError: no such table: raw.league_season
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[6], line 2
#       1 sql: str = "select id_season, id_league from raw.league_season"
# ----> 2 df: pd.DataFrame = db.get_df(sql)
#       3 df = df.reset_index()
#       4 season_league_dict = dict()
#
# File c:\Users\greg\OneDrive\My_Docs\Greg\work\code\Python\paddle_repo\datahub\utils\db.py:283, in get_df(sql, params)
# ...

# %%
print(df.columns)
